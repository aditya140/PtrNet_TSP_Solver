# %%
import pandas as pd

# %%
def clean(x):
    if x<1:
        x=1
    return x

# %%
import glob
files=glob.glob("./model_5*")
df={}
for file in files:
    num_points=int(file.split(".")[-2].split('_')[-1][3:])
    df[num_points]=pd.read_csv(file)
    df[num_points]["Model"]=df[num_points]["Model"].apply(clean)

# %%
print(df[10]["Nearest insertion"].mean())
print(df[10]["Nearest Neighbour"].mean())
print(df[10]["Farthest Neighbour"].mean())
print(df[10]["random"].mean())
print(df[10]["Google OR"].mean())
print(df[10]["Model"].mean())
# Out:
# 1.237236007727781
# 1.0406024749856153
# 1.40203403606403
# 1.2301011504807742
# 1.0
# 1.0028608911763162

# %%
x_ax=[]
model=[]
random=[]
farthest_neighbour=[]
nearest_insertion=[]
nearest_neighbour=[]
gor=[]
for n in sorted(df.keys()):
    x_ax.append(n)
    model.append(df[n].mean()["Model"])
    random.append(df[n].mean()["random"])
    farthest_neighbour.append(df[n].mean()["Farthest Neighbour"])
    nearest_insertion.append(df[n].mean()["Nearest insertion"])
    # nearest_neighbour.append(df[n].mean()["Nearest Neighbour"])
    gor.append(df[n].mean()["Google OR"])

# %%
import matplotlib.pyplot as plt
plt.plot(x_ax,model ,'-r',markersize=4, linestyle='--', marker='o',label='Model 10 Points')
plt.plot(x_ax,random,'-g',markersize=4, linestyle='--', marker='o',label='Random')
plt.plot(x_ax,farthest_neighbour,'-y',markersize=4, linestyle='--', marker='o',label='Farthest Neighbour')
plt.plot(x_ax,nearest_insertion,'-c',markersize=4, linestyle='--', marker='o',label='Nearest Insertion')
# plt.plot(x_ax,nearest_neighbour,'-c',markersize=4, linestyle='--', marker='o',label='Nearest Insertion')
plt.plot(x_ax,gor,'-b',markersize=4, linestyle='--', marker='o',label='Google OR tools')
plt.legend()
plt.ylabel('Optimality Gap')
plt.xlabel('Number of points')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Number of points')
collectn_1 = df[5]["Model"]
collectn_2 = df[10]["Model"]
collectn_3 = df[15]["Model"]
collectn_4 = df[20]["Model"]

## combine these different collections into a list
data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
labels = ['5', '10', '15', '20']

ax.set_ylabel('Oplimality Gap')
ax.set_title('Model 5')

set_axis_style(ax, labels)
# Create the boxplot
bp = ax.violinplot(data_to_plot)
# for pc in bp['bodies']:
#     pc.set_facecolor('blue')
#     pc.set_edgecolor('black')
#     pc.set_alpha(1)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
def set_axis_style(ax, labels):
    ax.get_xaxis().set_tick_params(direction='out')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xticks(np.arange(1, len(labels) + 1))
    ax.set_xticklabels(labels)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Number of points')
collectn_1 = df[5]["Nearest Neighbour"]
collectn_2 = df[10]["Nearest Neighbour"]
collectn_3 = df[15]["Nearest Neighbour"]
collectn_4 = df[20]["Nearest Neighbour"]

## combine these different collections into a list
data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
labels = ['5', '10', '15', '20']
ax.set_ylabel('Oplimality Gap')
ax.set_title('Nearest Insertion')

set_axis_style(ax, labels)
# Create the boxplot
bp = ax.violinplot(data_to_plot)

plt.show()

# %%
df[5].
